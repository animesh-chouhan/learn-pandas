# %% [markdown]
# # Learn Pandas
#
# Corey Schafer: https://www.youtube.com/playlist?list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS

# %%
import pandas as pd
pd.set_option("display.max_columns", 48)

# %%
df = pd.read_csv("data/survey_results_public.csv")

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %% [markdown]
# ## Constructing df from dict

# %%
people = {
    "first_name": ["Corey", "John", "Jane"],
    "last_name": ["Schafer", "Doe", "Doe"],
    "email": ["abc@gmail.com", "abc@yahoo.com", "abc@outlook.com"]
}

# %%
people["first_name"]
# Out:
# ['Corey', 'John', 'Jane']

# %%
df1 = pd.DataFrame(people)

# %%
df1.head()
# Out:
#   first_name last_name            email
# 0      Corey   Schafer    abc@gmail.com
# 1       John       Doe    abc@yahoo.com
# 2       Jane       Doe  abc@outlook.com

# %%
 df1["first_name"]
# Out:
# 0    Corey
# 1     John
# 2     Jane
# Name: first_name, dtype: object

# %%
df1.first_name
# Out:
# 0    Corey
# 1     John
# 2     Jane
# Name: first_name, dtype: object

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1["first_name"])
# Out:
# pandas.core.series.Series

# %%
df1[["first_name", "email"]]
# Out:
#   first_name            email
# 0      Corey    abc@gmail.com
# 1       John    abc@yahoo.com
# 2       Jane  abc@outlook.com

# %% [markdown]
# ## Accessing rows and columns

# %%
df1.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df1.iloc[1]
# Out:
# first_name             John
# last_name               Doe
# email         abc@yahoo.com
# Name: 1, dtype: object

# %%
df1.iloc[[0,1]]
# Out:
#   first_name last_name          email
# 0      Corey   Schafer  abc@gmail.com
# 1       John       Doe  abc@yahoo.com

# %%
df1.iloc[[0,1], 2]
# Out:
# 0    abc@gmail.com
# 1    abc@yahoo.com
# Name: email, dtype: object

# %%
df1
# Out:
#   first_name last_name            email
# 0      Corey   Schafer    abc@gmail.com
# 1       John       Doe    abc@yahoo.com
# 2       Jane       Doe  abc@outlook.com

# %%
df1.loc[[0,1]]
# Out:
#   first_name last_name          email
# 0      Corey   Schafer  abc@gmail.com
# 1       John       Doe  abc@yahoo.com

# %%
df1.loc[[0,1], "email"]
# Out:
# 0    abc@gmail.com
# 1    abc@yahoo.com
# Name: email, dtype: object

# %%
df1.loc[1, "email"]
# Out:
# 'abc@yahoo.com'

# %% [markdown]
# ## Back to the stackoverflow dataset

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df["Country"]
# Out:
# 0                                                 Slovakia
# 1                                              Netherlands
# 2                                       Russian Federation
# 3                                                  Austria
# 4        United Kingdom of Great Britain and Northern I...
#                                ...
# 83434                             United States of America
# 83435                                                Benin
# 83436                             United States of America
# 83437                                               Canada
# 83438                                               Brazil
# Name: Country, Length: 83439, dtype: object

# %%
df["Country"].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
df.loc[[0, 23, 44], "Country"]
# Out:
# 0     Slovakia
# 23      France
# 44      France
# Name: Country, dtype: object

# %% [markdown]
# ## Slicing

# %%
df.loc[0:4, "LearnCode":"OrgSize"]
# Out:
#                                            LearnCode YearsCode YearsCodePro  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN          NaN
# 1  Other online resources (ex: videos, blogs, etc...         7          NaN
# 2  Other online resources (ex: videos, blogs, etc...       NaN          NaN
# 3                                                NaN       NaN          NaN
# 4                            Friend or family member        17           10
#
#                                              DevType  \
# 0                                  Developer, mobile
# 1                                                NaN
# 2                                                NaN
# 3                               Developer, front-end
# 4  Developer, desktop or enterprise applications;...
#
#                                              OrgSize
# 0                                 20 to 99 employees
# 1                                                NaN
# ...

# %% [markdown]
# ## Index

# %%
df1.set_index("first_name")
# Out:
#            last_name            email
# first_name
# Corey        Schafer    abc@gmail.com
# John             Doe    abc@yahoo.com
# Jane             Doe  abc@outlook.com

# %%
df1
# Out:
#   first_name last_name            email
# 0      Corey   Schafer    abc@gmail.com
# 1       John       Doe    abc@yahoo.com
# 2       Jane       Doe  abc@outlook.com

# %%
df1.set_index("first_name", inplace=True)

# %%
df1
# Out:
#            last_name            email
# first_name
# Corey        Schafer    abc@gmail.com
# John             Doe    abc@yahoo.com
# Jane             Doe  abc@outlook.com

# %%
df1.index
# Out:
# Index(['Corey', 'John', 'Jane'], dtype='object', name='first_name')

# %%
df1.loc["Corey"]
# Out:
# last_name          Schafer
# email        abc@gmail.com
# Name: Corey, dtype: object

# %%
df1.loc["Corey", "last_name"]
# Out:
# 'Schafer'

# %%
df1.iloc[0]
# Out:
# last_name          Schafer
# email        abc@gmail.com
# Name: Corey, dtype: object

# %%
df1.reset_index(inplace=True)
df1
# Out:
#   first_name last_name            email
# 0      Corey   Schafer    abc@gmail.com
# 1       John       Doe    abc@yahoo.com
# 2       Jane       Doe  abc@outlook.com

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col="ResponseId")
schema_df = pd.read_csv("data/survey_results_schema.csv")

# %% [markdown]
# ## Filter

# %%
df1["last_name"] == "Doe"
# Out:
# 0    False
# 1     True
# 2     True
# Name: last_name, dtype: bool

# %%
filt = (df1["last_name"] == "Doe")
filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: last_name, dtype: bool

# %%
df1[filt]
# Out:
#   first_name last_name            email
# 1       John       Doe    abc@yahoo.com
# 2       Jane       Doe  abc@outlook.com

# %%
df1[df1["last_name"] == "Doe"]
# Out:
#   first_name last_name            email
# 1       John       Doe    abc@yahoo.com
# 2       Jane       Doe  abc@outlook.com

# %%
df1.loc[filt, "email"]
# Out:
# 1      abc@yahoo.com
# 2    abc@outlook.com
# Name: email, dtype: object

# %%
filt = (df1["last_name"] == "Doe") & (df1["first_name"] == "John")

# %%
df1.loc[filt]
# Out:
#   first_name last_name          email
# 1       John       Doe  abc@yahoo.com

# %%
filt = ~((df1["last_name"] == "Doe") & (df1["first_name"] == "John"))

# %%
df1.loc[filt]
# Out:
#   first_name last_name            email
# 0      Corey   Schafer    abc@gmail.com
# 2       Jane       Doe  abc@outlook.com

# %%
high_salary = (df["ConvertedCompYearly"] >= 100000)

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch  \
# ResponseId
# 19          I am not primarily a developer, but I write co...
# 32                             I am a developer by profession
# 37                             I am a developer by profession
# 38                             I am a developer by profession
# 63          I am not primarily a developer, but I write co...
# ...                                                       ...
# 83425                          I am a developer by profession
# 83428                          I am a developer by profession
# 83431                          I am a developer by profession
# 83435                          I am a developer by profession
# 83438                          I am a developer by profession
#
#                      Employment                   Country  \
# ResponseId
# 19          I prefer not to say                 Singapore
# 32           Employed full-time                    Israel
# ...

# %%
countries = ["United States of America", "Canada", "India"]

# %%
filt = df["Country"].isin(countries)
df.loc[filt]
# Out:
#                                         MainBranch           Employment  \
# ResponseId
# 6           I am a student who is learning to code   Student, part-time
# 7                      I code primarily as a hobby  I prefer not to say
# 9                   I am a developer by profession   Employed part-time
# 16          I am a student who is learning to code   Student, full-time
# 18                  I am a developer by profession   Employed full-time
# ...                                            ...                  ...
# 83431               I am a developer by profession   Employed full-time
# 83433               I am a developer by profession   Employed full-time
# 83435               I am a developer by profession   Employed full-time
# 83437               I am a developer by profession   Employed full-time
# 83438               I am a developer by profession   Employed full-time
#
#                              Country       US_State UK_Country  \
# ResponseId
# ...

# %%
filt = df["LanguageHaveWorkedWith"].str.contains("Python", na=False)
df.loc[filt, "LanguageHaveWorkedWith"]
# Out:
# ResponseId
# 2                                        JavaScript;Python
# 3                                 Assembly;C;Python;R;Rust
# 5                           Bash/Shell;HTML/CSS;Python;SQL
# 6        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 10                                              C++;Python
#                                ...
# 83430               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83431          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83432    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83437                                   Groovy;Java;Python
# 83438                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %% [markdown]
# ## Modifying Data

# %%
df1.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df1.columns = ['first', 'last_name', 'email']

# %%
df1
# Out:
#    first last_name            email
# 0  Corey   Schafer    abc@gmail.com
# 1   John       Doe    abc@yahoo.com
# 2   Jane       Doe  abc@outlook.com

# %%
df1.columns = [col.upper() for col in df1.columns]

# %%
df1
# Out:
#    FIRST LAST_NAME            EMAIL
# 0  Corey   Schafer    abc@gmail.com
# 1   John       Doe    abc@yahoo.com
# 2   Jane       Doe  abc@outlook.com

# %%
df1.columns = df1.columns.str.replace("_", " ")

# %%
df1
# Out:
#    FIRST LAST NAME            EMAIL
# 0  Corey   Schafer    abc@gmail.com
# 1   John       Doe    abc@yahoo.com
# 2   Jane       Doe  abc@outlook.com

# %%
df1 = pd.DataFrame(people)

# %%
df1.rename(columns={"first_name": "first"}, inplace=True)
df1
# Out:
#    first last_name            email
# 0  Corey   Schafer    abc@gmail.com
# 1   John       Doe    abc@yahoo.com
# 2   Jane       Doe  abc@outlook.com

# %%
df1.loc[2] = ["Jane", "Smith", "abc@email.com"]
df1
# Out:
#    first last_name          email
# 0  Corey   Schafer  abc@gmail.com
# 1   John       Doe  abc@yahoo.com
# 2   Jane     Smith  abc@email.com

# %%
df1.loc[2, ["first", "email"]] = ["Julie", "abc@outlook.com"]
df1
# Out:
#    first last_name            email
# 0  Corey   Schafer    abc@gmail.com
# 1   John       Doe    abc@yahoo.com
# 2  Julie     Smith  abc@outlook.com

# %%
df1.loc[2, "first"] = "Jane"
df1
# Out:
#    first last_name            email
# 0  Corey   Schafer    abc@gmail.com
# 1   John       Doe    abc@yahoo.com
# 2   Jane     Smith  abc@outlook.com

# %%
df1.at[2, "first"] = "Julie"
df1
# Out:
#    first last_name            email
# 0  Corey   Schafer    abc@gmail.com
# 1   John       Doe    abc@yahoo.com
# 2  Julie     Smith  abc@outlook.com

# %%
filt = (df1["email"] == "abc@gmail.com")

# %%
df1[filt]["last_name"] = "Flare"
# Out:
# /tmp/ipykernel_373541/1339799902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[filt]["last_name"] = "Flare"

# %%
df1.loc[filt, "last_name"] = "Flare"
df1
# Out:
#    first last_name            email
# 0  Corey     Flare    abc@gmail.com
# 1   John       Doe    abc@yahoo.com
# 2  Julie     Smith  abc@outlook.com

# %%
df1["email"] = df1["email"].str.lower()
df1
# Out:
#    first last_name            email
# 0  Corey     Flare    abc@gmail.com
# 1   John       Doe    abc@yahoo.com
# 2  Julie     Smith  abc@outlook.com

# %%
df1["email"].apply(len)
# Out:
# 0    13
# 1    13
# 2    15
# Name: email, dtype: int64

# %%
 df1["email"].apply(lambda x: x.upper())
# Out:
# 0      ABC@GMAIL.COM
# 1      ABC@YAHOO.COM
# 2    ABC@OUTLOOK.COM
# Name: email, dtype: object

# %%
df1.apply(len)
# Out:
# first        3
# last_name    3
# email        3
# dtype: int64

# %%
df1.apply(len, axis="columns")
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df1.apply(pd.Series.min)
# Out:
# first                Corey
# last_name              Doe
# email        abc@gmail.com
# dtype: object

# %%
df1.apply(lambda x: x.min())
# Out:
# first                Corey
# last_name              Doe
# email        abc@gmail.com
# dtype: object

# %%
df1.applymap(len)
# Out:
#    first  last_name  email
# 0      5          5     13
# 1      4          3     13
# 2      5          5     15

# %%
df1["first"].map({"Corey": "Chris", "Julie": "Mary"})
# Out:
# 0    Chris
# 1      NaN
# 2     Mary
# Name: first, dtype: object

# %%
df1["first"].replace({"Corey": "Chris", "Julie": "Mary"})
# Out:
# 0    Chris
# 1     John
# 2     Mary
# Name: first, dtype: object

# %% [markdown]
# ## Add/Remove Rows and Columns

# %%
df1["first"] + " " + df1["last_name"]
# Out:
# 0    Corey Flare
# 1       John Doe
# 2    Julie Smith
# dtype: object

# %%
df1["full_name"] = df1["first"] + " " + df1["last_name"]

# %%
df1
# Out:
#    first last_name            email    full_name
# 0  Corey     Flare    abc@gmail.com  Corey Flare
# 1   John       Doe    abc@yahoo.com     John Doe
# 2  Julie     Smith  abc@outlook.com  Julie Smith

# %%
df1.drop(columns=["first", "last_name"], inplace=True)

# %%
df1["full_name"].apply(str.split)
# Out:
# 0    [Corey, Flare]
# 1       [John, Doe]
# 2    [Julie, Smith]
# Name: full_name, dtype: object

# %%
df1["full_name"].str.split(" ", expand=True)
# Out:
#        0      1
# 0  Corey  Flare
# 1   John    Doe
# 2  Julie  Smith

# %%
df1
# Out:
#              email    full_name
# 0    abc@gmail.com  Corey Flare
# 1    abc@yahoo.com     John Doe
# 2  abc@outlook.com  Julie Smith

# %%
df1[["first", "last"]] = df1["full_name"].str.split(" ", expand=True)

# %%
df1
# Out:
#              email    full_name  first   last
# 0    abc@gmail.com  Corey Flare  Corey  Flare
# 1    abc@yahoo.com     John Doe   John    Doe
# 2  abc@outlook.com  Julie Smith  Julie  Smith

# %%
df1.append({"first": "Tony"}, ignore_index=True)
# Out:
# /tmp/ipykernel_373541/3811305710.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append({"first": "Tony"}, ignore_index=True)
#              email    full_name  first   last
# 0    abc@gmail.com  Corey Flare  Corey  Flare
# 1    abc@yahoo.com     John Doe   John    Doe
# 2  abc@outlook.com  Julie Smith  Julie  Smith
# 3              NaN          NaN   Tony    NaN

# %%
people = {
    "first": ["Tony", "Captain", "The"],
    "last": ["Stark", "America", "Hulk"],
    "email": ["abc@gmail.com", "abc@yahoo.com", "abc@outlook.com"]
}

# %%
df2 = pd.DataFrame(people)

# %%
df1.drop(columns=["full_name"], inplace=True)

# %%
pd.concat([df1, df2])
# Out:
#              email    first     last
# 0    abc@gmail.com    Corey    Flare
# 1    abc@yahoo.com     John      Doe
# 2  abc@outlook.com    Julie    Smith
# 0    abc@gmail.com     Tony    Stark
# 1    abc@yahoo.com  Captain  America
# 2  abc@outlook.com      The     Hulk

# %%
pd.concat([df1, df2], ignore_index=True)
# Out:
#              email    first     last
# 0    abc@gmail.com    Corey    Flare
# 1    abc@yahoo.com     John      Doe
# 2  abc@outlook.com    Julie    Smith
# 3    abc@gmail.com     Tony    Stark
# 4    abc@yahoo.com  Captain  America
# 5  abc@outlook.com      The     Hulk

# %%
df3 = pd.concat([df1, df2], ignore_index=True)
df3
# Out:
#              email    first     last
# 0    abc@gmail.com    Corey    Flare
# 1    abc@yahoo.com     John      Doe
# 2  abc@outlook.com    Julie    Smith
# 3    abc@gmail.com     Tony    Stark
# 4    abc@yahoo.com  Captain  America
# 5  abc@outlook.com      The     Hulk

# %%
df3.drop(index=4)
# Out:
#              email  first   last
# 0    abc@gmail.com  Corey  Flare
# 1    abc@yahoo.com   John    Doe
# 2  abc@outlook.com  Julie  Smith
# 3    abc@gmail.com   Tony  Stark
# 5  abc@outlook.com    The   Hulk

# %%
filt = (df3["last"] == "Doe")
df3[filt].index
# Out:
# Int64Index([1], dtype='int64')

# %%
df3.drop(df3[filt].index)
# Out:
#              email    first     last
# 0    abc@gmail.com    Corey    Flare
# 2  abc@outlook.com    Julie    Smith
# 3    abc@gmail.com     Tony    Stark
# 4    abc@yahoo.com  Captain  America
# 5  abc@outlook.com      The     Hulk

# %% [markdown]
# ## Sorting data

# %%
df3
# Out:
#              email    first     last
# 0    abc@gmail.com    Corey    Flare
# 1    abc@yahoo.com     John      Doe
# 2  abc@outlook.com    Julie    Smith
# 3    abc@gmail.com     Tony    Stark
# 4    abc@yahoo.com  Captain  America
# 5  abc@outlook.com      The     Hulk

# %%
df3.sort_values(by="last", ascending=False)
# Out:
#              email    first     last
# 3    abc@gmail.com     Tony    Stark
# 2  abc@outlook.com    Julie    Smith
# 5  abc@outlook.com      The     Hulk
# 0    abc@gmail.com    Corey    Flare
# 1    abc@yahoo.com     John      Doe
# 4    abc@yahoo.com  Captain  America

# %%
df3.sort_values(by=["last", "first"], ascending=[True, False], inplace=True)

# %%
df3
# Out:
#              email    first     last
# 4    abc@yahoo.com  Captain  America
# 1    abc@yahoo.com     John      Doe
# 0    abc@gmail.com    Corey    Flare
# 5  abc@outlook.com      The     Hulk
# 2  abc@outlook.com    Julie    Smith
# 3    abc@gmail.com     Tony    Stark

# %%
df3.sort_index()
# Out:
#              email    first     last
# 0    abc@gmail.com    Corey    Flare
# 1    abc@yahoo.com     John      Doe
# 2  abc@outlook.com    Julie    Smith
# 3    abc@gmail.com     Tony    Stark
# 4    abc@yahoo.com  Captain  America
# 5  abc@outlook.com      The     Hulk

# %%
df3["first"].sort_values()
# Out:
# 4    Captain
# 0      Corey
# 1       John
# 2      Julie
# 5        The
# 3       Tony
# Name: first, dtype: object

# %%
df["CompTotal"].nlargest(10)
# Out:
# ResponseId
# 6379     1.000000e+74
# 18920    8.000000e+52
# 62418    7.000000e+39
# 104      1.000000e+29
# 23553    1.000000e+25
# 45851    6.675636e+15
# 69036    4.162026e+15
# 39572    5.474577e+10
# 82157    3.500000e+10
# 37019    1.000000e+10
# Name: CompTotal, dtype: float64

# %%
df.nlargest(10, columns="CompTotal")
# Out:
#                                                    MainBranch  \
# ResponseId
# 6379                           I am a developer by profession
# 18920                          I am a developer by profession
# 62418                          I am a developer by profession
# 104                            I am a developer by profession
# 23553       I am not primarily a developer, but I write co...
# 45851                          I am a developer by profession
# 69036                          I am a developer by profession
# 39572                          I am a developer by profession
# 82157                          I am a developer by profession
# 37019                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 6379                                       Employed full-time
# 18920                                      Employed full-time
# 62418                                                 Retired
# ...

# %% [markdown]
# ## Grouping and Aggregating

# %%
df["CompTotal"].median()
# Out:
# 67000.0

# %%
df.median()
# Out:
# /tmp/ipykernel_373541/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal              67000.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedCompYearly
# count  4.718300e+04         4.684400e+04
# mean   2.119407e+69         1.184262e+05
# std    4.603702e+71         5.272944e+05
# min    0.000000e+00         1.000000e+00
# 25%    1.600000e+04         2.702500e+04
# 50%    6.700000e+04         5.621100e+04
# 75%    1.400000e+05         1.000000e+05
# max    1.000000e+74         4.524131e+07
